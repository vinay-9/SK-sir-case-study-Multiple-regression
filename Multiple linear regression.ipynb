# %% [markdown]
# ## Multiple linear regression
# In conventional methodds of regression(linear and poynomial regression) we take one independent variable and one dependent variable
# But in real life scenario we hafe multiple independent variable or multiple categories of a single independent  determining a single or multiple dependent variables
# Machine learning allows us to predict those kinds of scenarios such as sales comparison with respect to category and state and weather and many more..
# Similar kind of case study is taken into consideration for determining the profit of a company with respect to administration, R&D spend and marketing money spend in different states
# ~Source of Dataset--> www.Kaggle.com
#
# Performed by Vinay Chopra

# %%
# Multiple Linear Regression

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
df = pd.read_csv('marketing.csv')
dataset=pd.DataFrame(df)
dataset
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, 4]

#Convert the column into categorical columns
# doing one hot encoding

# %% [markdown]
# ##### Independent variables:
#     R&D Spend	Administration	Marketing Spend	State(subcategorized into multple states)
# ##### Dependent variable:
#     Profit

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
states=pd.get_dummies(X['State'],drop_first=True)

# Drop the state coulmn
X=X.drop('State',axis=1)
X=pd.DataFrame(X);
print(X)
# concat the dummy variables
# with the new table created


X=pd.concat([X,states],axis=1)
X=pd.DataFrame(X);

print(X)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# ...

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Predicting the Test set results
y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

# %%
pd.DataFrame(y_pred)
# Out:
#                0
# 0  103015.201598
# 1  132582.277608
# 2  132447.738452
# 3   71976.098513
# 4  178537.482211
# 5  116161.242302
# 6   67851.692097
# 7   98791.733747
# 8  113969.435330
# 9  167921.065696

# %% [markdown]
# ### |REGRESSOR SCORE

# %%
print("the regresosr score is:")
print(score*100," %")
# Out:
# the regresosr score is:
# 93.47068473282422  %

# %% [markdown]
# ## Graphical representation

# %%
import seaborn as sns

# %% [markdown]
# ### profit v/s marketing  comparison state wise

# %%
sns.lmplot(x='Marketing Spend',y='Profit', data=dataset, hue="State")

# %% [markdown]
# ### Comparison of actual vs predicted value

# %%
sns.regplot(y_test ,y_pred)

# %% [markdown]
# ### Pair wise comparison

# %%
sns.pairplot(dataset,hue="State",height=3, palette="rainbow")
